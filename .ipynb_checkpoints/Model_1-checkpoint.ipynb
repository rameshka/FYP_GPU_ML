# %%
import pandas as pd
import matplotlib.pyplot as plt



data = pd.read_csv("data.csv")
df = pd.DataFrame(data) # Converting data to Panda DataFrame
df.describe() #gives statistics about the columns of the dataframe
# Out:
#        instructionCount      ilp32     ilp256     ilp2048     ilp65536  \
# count      7.300000e+01  73.000000  73.000000   73.000000    73.000000
# mean       7.841356e+09   5.035029  10.276547   50.171639   578.065248
# std        1.336447e+10   1.597504   7.903931  118.187231  1874.925939
# min        2.611762e+06   1.442210   1.918572    1.980879     2.570037
# 25%        3.614952e+08   4.204724   4.346226    5.673349     6.526686
# 50%        2.216700e+09   5.666552   9.031183   10.028998    14.166241
# 75%        7.891953e+09   6.372240  13.011978   22.044238   149.512040
# max        6.800022e+10   7.197260  37.911765  534.000000  9023.000000
#
#           memops    ctrlops     intops      flops       coldref    ...      \
# count  73.000000  73.000000  73.000000  73.000000  7.300000e+01    ...
# mean    0.707404   0.113427   0.760920   0.188212  1.359374e+05    ...
# std     0.095986   0.068912   0.114903   0.143268  4.253537e+05    ...
# ...

# %%
df_Y = df[df['Class'] == "Y"]

plt.figure(figsize=(15,10))
plt.scatter(df_Y['instructionCount'], df_Y['CPU Time']) 
plt.title('Suitability VS CPU Time')
plt.xlabel('instruction count')
plt.ylabel('time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3b1c5af631b9> in <module>()
#       1 df_Y = df[df['Class'] == "Y"]
#       2
# ----> 3 plt.figure(figsize=(15,10))
#       4 plt.scatter(df_Y['instructionCount'], df_Y['CPU Time'])
#       5 plt.title('Suitability VS CPU Time')
#
# NameError: name 'plt' is not defined
